# %%
from PIL import Image
import IPython.display as display

image_path = r"C:\Users\Douglas\Desktop\TRUMP\1x\trump.png"
img = Image.open(image_path)
img_resized = img.resize((img.width // 2, img.height // 2))

display.display(img_resized)

text = "PolyMarket Analysis: How Trump's and Kamala's Odds Impact Bitcoin Price Movements – Don’t Miss This ML-Driven Future Prediction! Find Out Where Bitcoin's Price Could Go If They Win"
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=500x500>
# **PolyMarket Analysis: How Trump's and Kamala's Odds Impact Bitcoin Price Movements – Don’t Miss This ML-Driven Future Prediction! Find Out Where Bitcoin's Price Could Go If They Win**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\bitcoin_trump_time_series.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 2, img.height // 2))

# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "This chart shows a positive correlation between Bitcoin's price and Trump's election probability. As Trump's odds rise, Bitcoin's price tends to increase, suggesting investor optimism about his potential presidency, likely due to expected favorable economic policies."
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=700x350>
# **This chart shows a positive correlation between Bitcoin's price and Trump's election probability. As Trump's odds rise, Bitcoin's price tends to increase, suggesting investor optimism about his potential presidency, likely due to expected favorable economic policies.**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\TRUMP\Screenshot_10.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)

# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "🔍 R-squared (R² = 0.217): Explains 21.7% of Bitcoin's price variation based on candidate odds, indicating a moderate relationship. 📉 Durbin-Watson (0.117): A very low value, suggesting strong autocorrelation in the model's errors, which could impact prediction reliability."
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=292x213>
# **🔍 R-squared (R² = 0.217): Explains 21.7% of Bitcoin's price variation based on candidate odds, indicating a moderate relationship. 📉 Durbin-Watson (0.117): A very low value, suggesting strong autocorrelation in the model's errors, which could impact prediction reliability.**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\improved_multiple_regression_visualization.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 4, img.height // 4))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "This chart shows a trend where increased probability of Donald Trump winning correlates with a rise in Bitcoin price. The color gradient indicates different levels of Trump’s odds, with the red line representing a smoothed regression suggesting an upward trend."
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=626x409>
# **This chart shows a trend where increased probability of Donald Trump winning correlates with a rise in Bitcoin price. The color gradient indicates different levels of Trump’s odds, with the red line representing a smoothed regression suggesting an upward trend.**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\stacked_area_probabilities_with_bitcoin.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 2, img.height // 2))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "📊 This graph shows the relationship between Bitcoin's price and Trump's election probability. As Trump's odds increase (in orange hues), Bitcoin's price shows a slight upward trend, highlighted by the red regression line. Higher Trump probabilities are linked with potential BTC growth. 📈"
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=600x300>
# **📊 This graph shows the relationship between Bitcoin's price and Trump's election probability. As Trump's odds increase (in orange hues), Bitcoin's price shows a slight upward trend, highlighted by the red regression line. Higher Trump probabilities are linked with potential BTC growth. 📈**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\scatter_trump_bitcoin_price.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 4, img.height // 4))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "Interesting insight: As Trump's probability rises, Bitcoin seems to reflect a positive sentiment, with a correlation of 0.47. This trend suggests potential investor optimism tied to Trump's potential policies. The market reacts to political possibilities—fascinating stuff!"
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=742x518>
# **Interesting insight: As Trump's probability rises, Bitcoin seems to reflect a positive sentiment, with a correlation of 0.47. This trend suggests potential investor optimism tied to Trump's potential policies. The market reacts to political possibilities—fascinating stuff!**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\scatter_kamala_bitcoin_price.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 5, img.height // 5))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "As Kamala Harris's election probability rises, Bitcoin's price appears to show a slight negative trend. The weak negative correlation (r = -0.11) suggests a subtle inverse relationship, implying that optimism about her potential presidency might not favor Bitcoin as much as other candidates."
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=594x414>
# **As Kamala Harris's election probability rises, Bitcoin's price appears to show a slight negative trend. The weak negative correlation (r = -0.11) suggests a subtle inverse relationship, implying that optimism about her potential presidency might not favor Bitcoin as much as other candidates.**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\polynomial_regression_bitcoin_odds_donald_trump.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 5, img.height // 5))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "📊 The graph reveals an interesting relationship between Bitcoin prices and Donald Trump's election probability. Notice the polynomial trend: as BTC rises, so does Trump's chance, especially at higher values. Could optimism towards economic policies be a driver here?"
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=594x414>
# **📊 The graph reveals an interesting relationship between Bitcoin prices and Donald Trump's election probability. Notice the polynomial trend: as BTC rises, so does Trump's chance, especially at higher values. Could optimism towards economic policies be a driver here?**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\polynomial_regression_bitcoin_odds_kamala_harris.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 5, img.height // 5))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "The Kamala Harris chart shows a slight negative trend in Bitcoin price as her probability increases. This suggests a possible slight negative sentiment in the market with increasing odds for Harris. Not as impactful as Trump, but still worth considering. 📉🧠"
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=594x414>
# **The Kamala Harris chart shows a slight negative trend in Bitcoin price as her probability increases. This suggests a possible slight negative sentiment in the market with increasing odds for Harris. Not as impactful as Trump, but still worth considering. 📉🧠**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\logarithmic_regression_bitcoin_odds_donald_trump.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 5, img.height // 5))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "🔍 The log regression reveals a rising trend in Trump's probability as Bitcoin's price increases. Could this mean market optimism about Trump driving BTC gains? Let's break down how these correlations might indicate investor sentiment shaping Bitcoin's behavior! 📈✨"
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=594x414>
# **🔍 The log regression reveals a rising trend in Trump's probability as Bitcoin's price increases. Could this mean market optimism about Trump driving BTC gains? Let's break down how these correlations might indicate investor sentiment shaping Bitcoin's behavior! 📈✨**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\logarithmic_regression_bitcoin_odds_kamala_harris.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 5, img.height // 5))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "As we analyze Kamala Harris's chances, we see a slight decline correlated with Bitcoin prices. The logarithmic trend shows a negative association, suggesting investor uncertainty as her odds rise. Let's keep exploring these trends. 📉🔍"
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=594x414>
# **As we analyze Kamala Harris's chances, we see a slight decline correlated with Bitcoin prices. The logarithmic trend shows a negative association, suggesting investor uncertainty as her odds rise. Let's keep exploring these trends. 📉🔍**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\btc_price_predictions_trump_rf.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 5, img.height // 5))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "As we analyze Kamala Harris's chances, we see a slight decline correlated with Bitcoin prices. The logarithmic trend shows a negative association, suggesting investor uncertainty as her odds rise. Let's keep exploring these trends. 📉🔍"
display.display(display.Markdown(f"**{text}**"))
# Out:
# <PIL.Image.Image image mode=RGBA size=714x353>
# **As we analyze Kamala Harris's chances, we see a slight decline correlated with Bitcoin prices. The logarithmic trend shows a negative association, suggesting investor uncertainty as her odds rise. Let's keep exploring these trends. 📉🔍**

# %%
from PIL import Image
import IPython.display as display

# Caminho da imagem no seu computador
image_path = r"C:\Users\Douglas\Desktop\post\images\btc_price_predictions_kamala_rf.png"

# Carregar e redimensionar a imagem
img = Image.open(image_path)
img_resized = img.resize((img.width // 5, img.height // 5))
# Exibir a imagem
display.display(img_resized)

# Adicionar o texto explicativo logo abaixo da imagem
text = "As we analyze Kamala Harris's chances, we see a slight decline correlated with Bitcoin prices. The logarithmic trend shows a negative association, suggesting investor uncertainty as her odds rise. Let's keep exploring these trends. 📉🔍"
display.display(display.Markdown(f"**{text}**"))
